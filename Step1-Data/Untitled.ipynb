# %% [markdown]
# # Stock Price Analysis
#
# In this notebook, we will be analyzing the data I managed to find on Bloomberg for companies in the airline sector. This will give us a good idea of how to construct our portfolios

# %%
import numpy as np
import pandas as pd
import os

# %%
files = [x for x in os.listdir('stock_prices') if x != '.DS_Store']
files
# Out:
# ['NWA.csv',
#  'UAL.csv',
#  'SKYW.csv',
#  'SAVE.csv',
#  'LCC.csv',
#  'XJT.csv',
#  'VA.csv',
#  'JBLU.csv',
#  'HA.csv',
#  'ALGT.csv',
#  'AAI.csv',
#  'ANS.csv',
#  'FRNTQ.csv',
#  'GLUX.csv',
#  'ALK.csv',
#  'AAL.csv',
#  'LUV.csv',
#  'DAL.csv',
#  'MESA.csv',
#  'MEH.csv',
#  'RHWI.csv']

# %%
tickers = [x[:-4] for x in files]
tickers
# Out:
# ['NWA',
#  'UAL',
#  'SKYW',
#  'SAVE',
#  'LCC',
#  'XJT',
#  'VA',
#  'JBLU',
#  'HA',
#  'ALGT',
#  'AAI',
#  'ANS',
#  'FRNTQ',
#  'GLUX',
#  'ALK',
#  'AAL',
#  'LUV',
#  'DAL',
#  'MESA',
#  'MEH',
#  'RHWI']

# %%
prices
# Out:
#             AAI US Equity  AAL US Equity  ALGT US Equity  ALK US Equity  \
# Date
# 2001-01-02         6.8750            NaN             NaN         7.3906
# 2001-01-03         7.1875            NaN             NaN         7.9844
# 2001-01-04         7.3750            NaN             NaN         8.5000
# 2001-01-05         7.3750            NaN             NaN         8.4531
# 2001-01-08         7.3750            NaN             NaN         8.4688
# ...                   ...            ...             ...            ...
# 2021-07-26            NaN          22.08             NaN            NaN
# 2021-07-27            NaN          21.46             NaN            NaN
# 2021-07-28            NaN          21.63             NaN            NaN
# 2021-07-29            NaN          21.17             NaN            NaN
# 2021-07-30            NaN          20.38             NaN            NaN
#
#             ANS US Equity  AWAQC US Equity  DAL US Equity  FRNTQ US Equity  \
# Date
# 2001-01-02         3.8125              NaN            NaN          19.2083
# 2001-01-03         3.8125              NaN            NaN          20.3333
# 2001-01-04         3.8125              NaN            NaN          20.5625
# 2001-01-05         3.7500              NaN            NaN          21.1667
# 2001-01-08         3.7500              NaN            NaN          20.9583
# ...                   ...              ...            ...              ...
# 2021-07-26            NaN              NaN            NaN              NaN
# 2021-07-27            NaN              NaN            NaN              NaN
# 2021-07-28            NaN              NaN            NaN              NaN
# 2021-07-29            NaN              NaN            NaN              NaN
# 2021-07-30            NaN              NaN            NaN              NaN
#
#             FRNTQ US Equity.1  GLUX US Equity  ...  LUV US Equity  \
# Date                                           ...
# 2001-01-02            19.2083          0.9375  ...        22.3067
# 2001-01-03            20.3333          1.0625  ...        21.9067
# 2001-01-04            20.5625          1.0000  ...        23.1667
# 2001-01-05            21.1667             NaN  ...        23.2667
# 2001-01-08            20.9583          0.9375  ...        22.6667
# ...                       ...             ...  ...            ...
# 2021-07-26                NaN             NaN  ...            NaN
# 2021-07-27                NaN             NaN  ...            NaN
# 2021-07-28                NaN             NaN  ...            NaN
# 2021-07-29                NaN             NaN  ...            NaN
# 2021-07-30                NaN             NaN  ...            NaN
#
#             MEH US Equity  MESA US Equity  NWA US Equity  SAVE US Equity  \
# Date
# 2001-01-02        14.9375             NaN            NaN             NaN
# 2001-01-03        15.3125             NaN            NaN             NaN
# 2001-01-04        17.1875             NaN            NaN             NaN
# 2001-01-05        18.3750             NaN            NaN             NaN
# 2001-01-08        18.1250             NaN            NaN             NaN
# ...                   ...             ...            ...             ...
# 2021-07-26            NaN            9.37            NaN           28.94
# 2021-07-27            NaN            9.12            NaN           28.03
# 2021-07-28            NaN            9.19            NaN           28.51
# 2021-07-29            NaN            9.09            NaN           28.34
# 2021-07-30            NaN            8.92            NaN           26.98
#
#             SKYW US Equity  UAL US Equity  RHWI US Equity  XJT US Equity  \
# Date
# 2001-01-02         27.5000            NaN     58559.98829            NaN
# 2001-01-03         28.8125            NaN     68159.98637            NaN
# 2001-01-04         27.4375            NaN     73919.98522            NaN
# 2001-01-05         27.7500            NaN     68159.98637            NaN
# 2001-01-08         26.8750            NaN     71999.98560            NaN
# ...                    ...            ...             ...            ...
# 2021-07-26             NaN            NaN             NaN            NaN
# 2021-07-27             NaN            NaN             NaN            NaN
# 2021-07-28             NaN            NaN             NaN            NaN
# 2021-07-29             NaN            NaN             NaN            NaN
# 2021-07-30             NaN            NaN             NaN            NaN
#
#             VA US Equity
# Date
# 2001-01-02           NaN
# 2001-01-03           NaN
# 2001-01-04           NaN
# 2001-01-05           NaN
# 2001-01-08           NaN
# ...                  ...
# 2021-07-26           NaN
# 2021-07-27           NaN
# 2021-07-28           NaN
# 2021-07-29           NaN
# 2021-07-30           NaN
#
# [5177 rows x 23 columns]

# %%
counts = prices.count(axis=1)

# %%
prices.loc['2021-07-30']
# Out:
# AAI US Equity          NaN
# AAL US Equity        20.38
# ALGT US Equity         NaN
# ALK US Equity          NaN
# ANS US Equity          NaN
# AWAQC US Equity        NaN
# DAL US Equity          NaN
# FRNTQ US Equity        NaN
# FRNTQ US Equity.1      NaN
# GLUX US Equity         NaN
# HA US Equity           NaN
# JBLU US Equity         NaN
# LCC US Equity          NaN
# LUV US Equity          NaN
# MEH US Equity          NaN
# MESA US Equity        8.92
# NWA US Equity          NaN
# SAVE US Equity       26.98
# SKYW US Equity         NaN
# UAL US Equity          NaN
# RHWI US Equity         NaN
# XJT US Equity          NaN
# VA US Equity           NaN
# Name: 2021-07-30, dtype: float64
