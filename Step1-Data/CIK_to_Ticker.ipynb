# %% [markdown]
# # Importing Market Data from Yahoo! Finance
#
# In this notebook, I will be finding the ticker symbols of the companies in this universe. This will not be simple as the names of companies change over time and there is often M\&A activity that interferes with this process. This will be a learning experience so I will need to adjust as I go!

# %%
import numpy as np
import pandas as pd
import os
import urllib.request

import yfinance

# %% [markdown]
# We have a CIK-to-company mapping that was downloaded in another notebook (#ToDo), so let's see if we can use that to help us:

# %%
map_df = pd.read_csv('cik_ticker.csv')
map_df.head()
# Out:
#        CIK Ticker                              Name Exchange     SIC Business  \
# 0  1090872      A          Agilent Technologies Inc     NYSE  3825.0       CA
# 1     4281     AA                         Alcoa Inc     NYSE  3350.0       PA
# 2  1332552  AAACU  Asia Automotive Acquisition Corp      NaN  6770.0       DE
# 3  1287145   AABB                Asia Broadband Inc      OTC  8200.0       GA
# 4  1024015   AABC        Access Anytime Bancorp Inc      NaN  6035.0       NM
#
#   Incorporated          IRS
# 0           DE  770518772.0
# 1           PA  250317820.0
# 2           DE  203022522.0
# 3           NV  721569126.0
# 4           DE  850444597.0

# %%
os.listdir('sec-edgar-filings/')
# Out:
# ['0000100517',
#  '0001351548',
#  '0000101001',
#  'AAL',
#  '0001405419',
#  '0001614436',
#  '0001144331',
#  '0001166291',
#  '0000921929',
#  '0000899394',
#  '.DS_Store',
#  '0001159154',
#  '0001498710',
#  '0000714560',
#  '0000869187',
#  '0000319687',
#  '0000027904',
#  '0000006201',
#  '0001050715',
#  '0000904020',
#  '0000706270',
#  '0000810332',
#  '0001029863',
#  '0000948845',
#  '0001172222',
#  '0000766421',
#  '0001058033',
#  '0000835768',
#  '0000793733',
#  '0000092380',
#  '0000004515',
#  '0001088734',
#  '0001158463',
#  '0001362468',
#  '0001011696',
#  '0000003202',
#  '0000948846',
#  '0000914397',
#  '0001000578',
#  '0000701345',
#  '0000046205']

# %%
CIKS = [int(x.lstrip('0')) for x in os.listdir('sec-edgar-filings/') if x != 'AAL' and x != '.DS_Store']
CIKS
# Out:
# [100517,
#  1351548,
#  101001,
#  1405419,
#  1614436,
#  1144331,
#  1166291,
#  921929,
#  899394,
#  1159154,
#  1498710,
#  714560,
#  869187,
#  319687,
#  27904,
#  6201,
#  1050715,
#  904020,
#  706270,
#  810332,
#  1029863,
#  948845,
#  1172222,
#  766421,
#  1058033,
#  835768,
#  793733,
#  92380,
#  4515,
#  1088734,
#  1158463,
#  1362468,
#  1011696,
#  3202,
#  948846,
#  914397,
#  1000578,
#  701345,
#  46205]

# %%
import json

with open('company_tickers_exchange.json') as f:
  df = json.load(f)

# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}
print(df)
# Out:
# {'fields': ['cik', 'name', 'ticker', 'exchange'], 'data': [[320193, 'Apple Inc.', 'AAPL', 'Nasdaq'], [789019, 'MICROSOFT CORP', 'MSFT', 'Nasdaq'], [1018724, 'AMAZON COM INC', 'AMZN', 'Nasdaq'], [1652044, 'Alphabet Inc.', 'GOOG', 'Nasdaq'], [1318605, 'Tesla, Inc.', 'TSLA', 'Nasdaq'], [1067983, 'BERKSHIRE HATHAWAY INC', 'BRK-A', 'NYSE'], [1046179, 'TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD', 'TSM', 'NYSE'], [1293451, 'Tencent Holdings Ltd', 'TCEHY', 'OTC'], [1403161, 'VISA INC.', 'V', 'NYSE'], [1577552, 'Alibaba Group Holding Ltd', 'BABA', 'NYSE'], [19617, 'JPMORGAN CHASE & CO', 'JPM', 'NYSE'], [200406, 'JOHNSON & JOHNSON', 'JNJ', 'NYSE'], [824046, 'LVMH MOET HENNESSY LOUIS VUITTON', 'LVMUY', 'OTC'], [884394, 'SPDR S&P 500 ETF TRUST', 'SPY', 'NYSE'], [104169, 'Walmart Inc.', 'WMT', 'NYSE'], [731766, 'UNITEDHEALTH GROUP INC', 'UNH', 'NYSE'], [1141391, 'Mastercard Inc', 'MA', 'NYSE'], [354950, 'HOME DEPOT, INC.', 'HD', 'NYSE'], [80424, 'PROCTER & GAMBLE Co', 'PG', 'NYSE'], [1633917, 'PayPal Holdings, Inc.', 'PYPL', 'Nasdaq'], [70858, 'BANK OF AMERICA CORP /DE/', 'BAC', 'NYSE'], [1744489, 'Walt Disney Co', 'DIS', 'NYSE'], [937966, 'ASML HOLDING NV', 'ASML', 'Nasdaq'], [796343, 'ADOBE INC.', 'ADBE', 'Nasdaq'], [1166691, 'COMCAST CORP', 'CMCSA', 'Nasdaq'], [320187, 'NIKE, Inc.', 'NKE', 'NYSE'], [1094517, 'TOYOTA MOTOR CORP/', 'TM', 'NYSE'], [34088, 'EXXON MOBIL CORP', 'XOM', 'NYSE'], [21344, 'COCA COLA CO', 'KO', 'NYSE'], [1341439, 'ORACLE CORP', 'ORCL', 'NYSE'], [78003, 'PFIZER INC', 'PFE', 'NYSE'], [59478, 'ELI LILLY & Co', 'LLY', 'NYSE'], [1445468, 'Industrial & Commercial Bank of China', 'IDCBY', 'OTC'], [858877, 'CISCO SYSTEMS, INC.', 'CSCO', 'Nasdaq'], [732712, 'VERIZON COMMUNICATIONS INC', 'VZ', 'NYSE'], [1065280, 'NETFLIX INC', 'NFLX', 'Nasdaq'], [1108524, 'SALESFORCE.COM, INC.', 'CRM', 'NYSE'], [50863, 'INTEL CORP', 'INTC', 'Nasdaq'], [77476, 'PEPSICO INC', 'PEP', 'Nasdaq'], [1800, 'ABBOTT LABORATORIES', 'ABT', 'NYSE'], [1450488, 'Christian Dior SE/ADR', 'CHDRY', 'OTC'], [313616, 'DANAHER CORP /DE/', 'DHR', 'NYSE'], [353278, 'NOVO NORDISK A S', 'NVO', 'NYSE'], [1551152, 'AbbVie Inc.', 'ABBV', 'NYSE'], [97745, 'THERMO FISHER SCIENTIFIC INC.', 'TMO', 'NYSE'], [1114448, 'NOVARTIS AG', 'NVS', 'NYSE'], [811809, 'BHP Group Ltd', 'BHP', 'NYSE'], [1467373, 'Accenture plc', 'ACN', 'NYSE'], [732717, 'AT&T INC.', 'T', 'NYSE'], [1341439, 'ORACLE CORP', 'ORCL', 'NYSE'], [1730168, 'Broadcom Inc.', 'AVGO', 'Nasdaq'], [93410, 'CHEVRON CORP', 'CVX', 'NYSE'], [1495688, 'China Merchants Bank Co., Ltd./ADR/', 'CIHKY', 'OTC'], [310158, 'Merck & Co., Inc.', 'MRK', 'NYSE'], [72971, 'WELLS FARGO & COMPANY/MN', 'WFC', 'NYSE'], [909832, 'COSTCO WHOLESALE CORP /NEW', 'COST', 'Nasdaq'], [1594805, 'SHOPIFY INC.', 'SHOP', 'NYSE'], [1330306, 'VESTAS WIND SYSTEMS A/S', 'VWDRY', 'OTC'], [63908, 'MCDONALDS CORP', 'MCD', 'NYSE'], [1283699, 'T-Mobile US, Inc.', 'TMUS', 'Nasdaq'], [895421, 'MORGAN STANLEY', 'MS', 'NYSE'], [1613103, 'Medtronic plc', 'MDT', 'NYSE'], [97476, 'TEXAS INSTRUMENTS INC', 'TXN', 'Nasdaq'], [1445474, 'China Construction Bank Corp', 'CICHY', 'OTC'], [804328, 'QUALCOMM INC/DE', 'QCOM', 'Nasdaq'], [1000184, 'SAP SE', 'SAP', 'NYSE'], [1090727, 'UNITED PARCEL SERVICE INC', 'UPS', 'NYSE'], [1171264, 'BHP Group Plc', 'BBL', 'NYSE'], [887028, 'RIO TINTO LTD', 'RTNTF', 'OTC'], [773840, 'HONEYWELL INTERNATIONAL INC', 'HON', 'Nasdaq'], [1436949, 'HERMES INTERNATIONAL S.C.A.', 'HESAY', 'OTC'], [1306965, 'Royal Dutch Shell plc', 'RDS-A', 'NYSE'], [1413329, 'Philip Morris International Inc.', 'PM', 'NYSE'], [1707925, 'LINDE PLC', 'LIN', 'NYSE'], [1501437, 'Agricultural Bank of China Limited/ADR', 'ACGBY', 'OTC'], [14272, 'BRISTOL MYERS SQUIBB CO', 'BMY', 'NYSE'], [753308, 'NEXTERA ENERGY INC', 'NEE', 'NYSE'], [901832, 'ASTRAZENECA PLC', 'AZN', 'Nasdaq'], [217410, 'UNILEVER PLC', 'UL', 'NYSE'], [1703399, 'Sea Ltd', 'SE', 'NYSE'], [1000275, 'ROYAL BANK OF CANADA', 'RY', 'NYSE'], [100885, 'UNION PACIFIC CORP', 'UNP', 'NYSE'], [829224, 'STARBUCKS CORP', ' ...

# %%
[x for x in df['data'] if x[0] in CIKS]
# Out:
# [[92380, 'SOUTHWEST AIRLINES CO', 'LUV', 'NYSE'],
#  [27904, 'DELTA AIR LINES, INC.', 'DAL', 'NYSE'],
#  [100517, 'United Airlines Holdings, Inc.', 'UAL', 'Nasdaq'],
#  [6201, 'American Airlines Group Inc.', 'AAL', 'Nasdaq'],
#  [766421, 'ALASKA AIR GROUP, INC.', 'ALK', 'NYSE'],
#  [1158463, 'JETBLUE AIRWAYS CORP', 'JBLU', 'Nasdaq'],
#  [1362468, 'Allegiant Travel CO', 'ALGT', 'Nasdaq'],
#  [1498710, 'Spirit Airlines, Inc.', 'SAVE', 'NYSE'],
#  [793733, 'SKYWEST INC', 'SKYW', 'Nasdaq'],
#  [1172222, 'HAWAIIAN HOLDINGS INC', 'HA', 'Nasdaq'],
#  [810332, 'MESA AIR GROUP INC', 'MESA', 'Nasdaq'],
#  [899394, 'HARBOR DIVERSIFIED, INC.', 'HRBR', 'OTC']]

# %%
res = map_df[map_df['CIK'].isin(CIKS)]
res
# Out:
#            CIK Ticker                                Name  Exchange     SIC  \
# 9       948846    AAI                Airtran Holdings Inc       NaN  4512.0
# 12        6201    AAL         American Airlines Group Inc    NASDAQ  4512.0
# 104     904020   ACAI                            Flyi Inc       NaN  4512.0
# 497    1362468   ALGT                 Allegiant Travel Co    NASDAQ  4512.0
# 502     766421    ALK                Alaska Air Group Inc      NYSE  4512.0
# 722    1011696    ANS                  Airnet Systems Inc  NYSE MKT  4512.0
# 1182   1029863    AWA          America West Holdings Corp       NaN  4512.0
# 1623    869187   BLTA                Baltia Air Lines Inc       OTC  4512.0
# 1995    319687    CAL                 United Airlines Inc       NaN  4512.0
# 3303     27904    DAL                 Delta Air Lines Inc      NYSE  4512.0
# 4866    921929   FRNT               Frontier Airlines Inc       NaN  4512.0
# 4867   1351548   FRNT      Frontier Airlines Holdings Inc       NaN  4512.0
# 5197   1405419    GIA  Gulfstream International Group Inc  NYSE MKT  4512.0
# 5269    914397   GLUX            Great Lakes Aviation LTD       OTC  4512.0
# 5568   1172222     HA               Hawaiian Holdings Inc    NASDAQ  4512.0
# 5887    899394   HRBR              Harbor Biosciences Inc       OTC  2834.0
# 6664   1158463   JBLU                Jetblue Airways Corp    NASDAQ  4512.0
# 7072    701345    LCC                US Airways Group Inc      NYSE  4512.0
# 7370     92380    LUV               Southwest Airlines Co      NYSE  4512.0
# 7432    835768   MAIR                 Mesaba Holdings Inc       NaN  4512.0
# 7645    948845    MEH               Midwest Air Group Inc  NYSE MKT  4512.0
# 7670    810332   MESA                  Mesa Air Group Inc       NaN  4512.0
# 8866   1058033   NWAC             Northwest Airlines Corp      NYSE  4512.0
# 9774   1166291   PNCL              Pinnacle Airlines Corp       NaN  4512.0
# 10450  1159154   RJET       Republic Airways Holdings Inc    NASDAQ  4512.0
# 10759  1498710   SAVE                 Spirit Airlines Inc    NASDAQ  4512.0
# 11164   793733   SKYW                         Skywest Inc    NASDAQ  4512.0
# 12540   100517    UAL     United Continental Holdings Inc      NYSE  4512.0
# 12933  1088734   VIVI             River Hawk Aviation Inc       NaN  4512.0
# 13555  1144331    XJT             Expressjet Holdings Inc      NYSE  4512.0
#
#       Business Incorporated          IRS
# 9           FL           NV  582189551.0
# 12          TX           DE  751825172.0
# 104         VA           DE  133621051.0
# 497         NV           NV  204745737.0
# 502         WA           DE  911292054.0
# 722         OH           OH  311458309.0
# 1182        AZ           DE  860847214.0
# 1623        NY           NY  112989648.0
# 1995        IL           DE  742099724.0
# 3303        GA           DE  580218548.0
# 4866        CO           CO  841256945.0
# 4867        CO           DE  204191157.0
# 5197        FL           DE  203973956.0
# 5269        WY           IA  411135319.0
# 5568        HI           DE  710879698.0
# 5887        CA           DE  133697002.0
# 6664        NY           DE  870617894.0
# 7072        AZ           DE  541194634.0
# 7370        TX           TX  741563240.0
# 7432        MN           MN  411616499.0
# 7645        WI           WI  391828757.0
# 7670        AZ           NV  850302351.0
# 8866        MN           DE  411905580.0
# 9774        TN           DE   30376558.0
# 10450       IN           DE   61449146.0
# 10759       FL           DE  381747023.0
# 11164       UT           UT  870292166.0
# 12540       IL           DE  362675207.0
# 12933       MI           DE  223537927.0
# 13555       TX           DE  760517977.0

# %%
res.to_csv("almost_done_maps.csv")

# %%
len(res)
# Out:
# 30

# %%
len(CIKS)
# Out:
# 39

# %%
res['CIK']
# Out:
# 9         948846
# 12          6201
# 104       904020
# 497      1362468
# 502       766421
# 722      1011696
# 1182     1029863
# 1623      869187
# 1995      319687
# 3303       27904
# 4866      921929
# 4867     1351548
# 5197     1405419
# 5269      914397
# 5568     1172222
# 5887      899394
# 6664     1158463
# 7072      701345
# 7370       92380
# 7432      835768
# 7645      948845
# 7670      810332
# 8866     1058033
# 9774     1166291
# 10450    1159154
# 10759    1498710
# 11164     793733
# 12540     100517
# 12933    1088734
# 13555    1144331
# Name: CIK, dtype: int64

# %%
bads = [x for x in CIKS if x not in res["CIK"].values]
bads
# Out:
# [101001, 1614436, 714560, 1050715, 706270, 4515, 3202, 1000578, 46205]

# %% [markdown]
# There are a handful leftover, we may need to manually map these to their tickers in order to get a clean enough dataset. For this, I will use the following database http://rankandfiled.com/#/data/tickers to find the necessary information

# %%
count = 0
for CIK in os.listdir('sec-edgar-filings/'):
    try:
        print(map_df[map_df["CIK"] == int(CIK.lstrip('0'))])
        count += 1
    except:
        continue
# Out:
#         CIK                         Company State/Country
# 107  100517  United Airlines Holdings, Inc.            IL
#         CIK                           Company State/Country
# 52  1351548  Frontier Airlines Holdings, Inc.            CO
#         CIK                 Company State/Country
# 106  101001  UNITED AIR LINES, INC.            IL
#         CIK                             Company State/Country
# 58  1405419  GULFSTREAM INTERNATIONAL GROUP INC            FL
#          CIK              Company State/Country
# 119  1614436  Virgin America Inc.            CA
#         CIK                  Company State/Country
# 48  1144331  EXPRESSJET HOLDINGS INC            TX
#         CIK                 Company State/Country
# 84  1166291  PINNACLE AIRLINES CORP            TN
#        CIK                     Company State/Country
# 53  921929  FRONTIER AIRLINES INC /CO/            CO
#        CIK                   Company State/Country
# 59  899394  HARBOR DIVERSIFIED, INC.            WI
#         CIK                        Company State/Country
# 88  1159154  REPUBLIC AIRWAYS HOLDINGS INC            IN
#         CIK                Company State/Country
# 96  1498710  Spirit Airlines, Inc.            FL
#         CIK         Company State/Country
# 110  714560  US AIRWAYS INC            AZ
#        CIK               Company State/Country
# 26  869187  BALTIA AIR LINES INC            NY
#         CIK                Company State/Country
# 108  319687  UNITED AIRLINES, INC.            IL
#       CIK                Company State/Country
# 43  27904  DELTA AIR LINES, INC.            GA
#      CIK                       Company State/Country
# 19  6201  American Airlines Group Inc.            TX
#         CIK              Company State/Country
# 10  1050715  AIRTRAN AIRWAYS INC            FL
#        CIK   Company State/Country
# 49  904020  FLYI INC            VA
#        CIK                    Company State/Country
# 17  706270  AMERICA WEST AIRLINES INC            AZ
#        CIK             Company State/Country
# 71  810332  MESA AIR GROUP INC            AZ
#         CIK                     Company State/Country
# 18  1029863  AMERICA WEST HOLDINGS CORP            AZ
#        CIK                Company State/Country
# 76  948845  MIDWEST AIR GROUP INC            WI
#         CIK                Company State/Country
# 61  1172222  HAWAIIAN HOLDINGS INC            HI
#        CIK                 Company State/Country
# 13  766421  ALASKA AIR GROUP, INC.            WA
#         CIK                  Company State/Country
# 79  1058033  NORTHWEST AIRLINES CORP            MN
#        CIK            Company State/Country
# 68  835768  MAIR HOLDINGS INC            MN
#        CIK      Company State/Country
# 94  793733  SKYWEST INC            UT
#       CIK                Company State/Country
# 95  92380  SOUTHWEST AIRLINES CO            TX
#      CIK                  Company State/Country
# 20  4515  AMERICAN AIRLINES, INC.            TX
#         CIK                  Company State/Country
# 91  1088734  RIVER HAWK AVIATION INC            MI
#         CIK               Company State/Country
# 63  1158463  JETBLUE AIRWAYS CORP            NY
#         CIK              Company State/Country
# 15  1362468  Allegiant Travel CO            NV
#        CIK             Company State/Country
# 8  1011696  AIRNET SYSTEMS INC            OH
#      CIK              Company State/Country
# 14  3202  ALASKA AIRLINES INC            WA
#        CIK               Company State/Country
# 11  948846  AIRTRAN HOLDINGS INC            FL
#        CIK                   Company State/Country
# 57  914397  GREAT LAKES AVIATION LTD            WY
#          CIK                     Company State/Country
# 118  1000578  VANGUARD AIRLINES INC \DE\            MO
#         CIK               Company State/Country
# 109  701345  US AIRWAYS GROUP INC            AZ
#       CIK                   Company State/Country
# 60  46205  HAWAIIAN AIRLINES INC/HI            HI

# %%
count
# Out:
# 39

# %%
sum(map_df['CIK'] == int(candidate))
# Out:
# 1

# %%
# uurl = 'https://www.sec.gov/include/ticker.txt'

# def download(t_url):
#     response =  urllib.request.urlopen(t_url)
#     data = response.read()
#     txt_str = str(data)
#     lines = txt_str.split("\\n")
#     des_url = 'ticker_to_CIK.csv'
#     fx = open(des_url,"w")
#     for line in lines:
#         fx.write(line+ "\n")
#     fx.close()

# download(uurl)

# %%
os.listdir()
# Out:
# ['company_list.csv',
#  'all_stock_parse.ipynb',
#  '.DS_Store',
#  'master.idx',
#  'edgar_scrape.ipynb',
#  'AAL_Parse_Item7Only.ipynb',
#  'ticker_to_CIK.txt',
#  'cik_ticker.csv',
#  'sec-edgar-filings',
#  'AAL_parse.ipynb',
#  'AAL_parsed.pickle',
#  'CIK_to_Ticker.ipynb',
#  '.ipynb_checkpoints',
#  'ticker_to_CIK.csv',
#  'cik_ticker.csv.download']

# %%
ticker_to_CIK = pd.read_table('ticker_to_CIK.txt', sep=r'\\t', header=None)
ticker_to_CIK.head()
# Out:
# /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#         0        1
# 0  b'aapl   320193
# 1    msft   789019
# 2    amzn  1018724
# 3    goog  1652044
# 4   tcehy  1293451

# %%
all([type(x) == str for x in ticker_to_CIK.loc[:,1]])
# Out:
# True

# %%
# Fix weird apple entry
ticker_to_CIK.iloc[0,0] = 'aapl'
ticker_to_CIK.head()
# Out:
#        0        1
# 0   aapl   320193
# 1   msft   789019
# 2   amzn  1018724
# 3   goog  1652044
# 4  tcehy  1293451

# %%
ticker_to_CIK.tail()
# Out:
#              0         1
# 12852   aac-wt   1829432
# 12853  aaic-pb   1209028
# 12854  aaic-pc   1209028
# 12855  aaqc-un   1838883
# 12856  aaqc-wt  1838883'

# %%
# Fix weird aaqc CIK entry
ticker_to_CIK.iloc[-1,1] = '1838883'
ticker_to_CIK.tail()
# Out:
#              0        1
# 12852   aac-wt  1829432
# 12853  aaic-pb  1209028
# 12854  aaic-pc  1209028
# 12855  aaqc-un  1838883
# 12856  aaqc-wt  1838883

# %%
ticker_to_CIK[1].values
# Out:
# array(['320193', '789019', '1018724', ..., '1209028', '1838883',
#        '1838883'], dtype=object)

# %%
CIKS
# Out:
# [100517,
#  1351548,
#  101001,
#  1405419,
#  1614436,
#  1144331,
#  1166291,
#  921929,
#  899394,
#  1159154,
#  1498710,
#  714560,
#  869187,
#  319687,
#  27904,
#  6201,
#  1050715,
#  904020,
#  706270,
#  810332,
#  1029863,
#  948845,
#  1172222,
#  766421,
#  1058033,
#  835768,
#  793733,
#  92380,
#  4515,
#  1088734,
#  1158463,
#  1362468,
#  1011696,
#  3202,
#  948846,
#  914397,
#  1000578,
#  701345,
#  46205]

# %%
ticker_to_CIK[ticker_to_CIK[1].isin(CIKS)]
# Out:
#          0        1
# 479    luv    92380
# 539    dal    27904
# 802    ual   100517
# 915    aal     6201
# 1336   alk   766421
# 1635  jblu  1158463
# 2092  save  1498710
# 2132  algt  1362468
# 2489  skyw   793733
# 3103    ha  1172222
# 4675  mesa   810332
# 6047  hrbr   899394

# %% [markdown]
# So now we have a mapping from CIK to ticker. However, this is not quite the end of this process. The CIKs in the edgar file directory appear to have zeroes padded at the beginning, and these CIKs do not contain those zeroes. For this reason, we will need to accommodate

# %%
sample = ticker_to_CIK[ticker_to_CIK[0] == 'aal']
sample
# Out:
#        0     1
# 915  aal  6201

# %%
[x for x in os.listdir("sec-edgar-filings/") if x[-len('6201'):] == '6201']
# Out:
# ['0000006201']

# %%
ticker_to_CIK = ticker_to_CIK.set_index(1)

# %%
for CIK in os.listdir("sec-edgar-filings/"):
    candidate = CIK.lstrip('0')
    print(candidate, candidate in ticker_to_CIK.index)
    #print(ticker_to_CIK.loc['320193',:])
# Out:
# 100517 True
# 1351548 False
# 101001 False
# AAL False
# 1405419 False
# 1614436 False
# 1144331 False
# 1166291 False
# 921929 False
# 899394 True
# .DS_Store False
# 1159154 False
# 1498710 True
# 714560 False
# 869187 False
# 319687 False
# 27904 True
# 6201 True
# 1050715 False
# 904020 False
# 706270 False
# 810332 True
# 1029863 False
# 948845 False
# 1172222 True
# 766421 True
# 1058033 False
# 835768 False
# 793733 True
# 92380 True
# 4515 False
# 1088734 False
# 1158463 True
# 1362468 True
# 1011696 False
# 3202 False
# 948846 False
# 914397 False
# 1000578 False
# 701345 False
# 46205 False

# %%
ticker_to_CIK
# Out:
#                0
# 1
# 320193      aapl
# 789019      msft
# 1018724     amzn
# 1652044     goog
# 1293451    tcehy
# ...          ...
# 1829432   aac-wt
# 1209028  aaic-pb
# 1209028  aaic-pc
# 1838883  aaqc-un
# 1838883  aaqc-wt
#
# [12857 rows x 1 columns]

# %%
companies = pd.DataFrame([x for x in os.listdir('sec-edgar-filings/') if len(x) == 10])
companies[:5]
# Out:
#             0
# 0  0000100517
# 1  0001351548
# 2  0000101001
# 3  0001405419
# 4  0001614436

# %%
len([x for x in companies[0] if x not in ticker_to_CIK.index])
# Out:
# 27

# %%
len(companies)
# Out:
# 39

# %%
companies[0].map(lambda x: ticker_to_CIK.loc[x][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: '0001351548'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-388e7fe0d90f> in <module>
# ----> 1 companies[0].map(lambda x: ticker_to_CIK.loc[x][0])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3907         dtype: object
#    3908         """
# -> 3909         new_values = super()._map_values(arg, na_action=na_action)
#    3910         return self._constructor(new_values, index=self.index).__finalize__(
#    3911             self, method="map"
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     935
#     936         # mapper is a function
# --> 937         new_values = map_f(values, mapper)
#     938
#     939         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-77-388e7fe0d90f> in <lambda>(x)
# ----> 1 companies[0].map(lambda x: ticker_to_CIK.loc[x][0])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '0001351548'

# %%
'0001351548' in ticker_to_CIK.index
# Out:
# False

# %%
companies
# Out:
#              0
# 0   0000100517
# 1   0001351548
# 2   0000101001
# 3   0001405419
# 4   0001614436
# 5   0001144331
# 6   0001166291
# 7   0000921929
# 8   0000899394
# 9   0001159154
# 10  0001498710
# 11  0000714560
# 12  0000869187
# 13  0000319687
# 14  0000027904
# 15  0000006201
# 16  0001050715
# 17  0000904020
# 18  0000706270
# 19  0000810332
# 20  0001029863
# 21  0000948845
# 22  0001172222
# 23  0000766421
# 24  0001058033
# 25  0000835768
# 26  0000793733
# 27  0000092380
# 28  0000004515
# 29  0001088734
# 30  0001158463
# 31  0001362468
# 32  0001011696
# 33  0000003202
# 34  0000948846
# 35  0000914397
# 36  0001000578
# 37  0000701345
# 38  0000046205

# %%
ticker_to_CIK.sort_values(0)[-1030:-1000]
# Out:
#                  0        1
# padded
# 0001821424      uk  1821424
# 0001821424   ukomw  1821424
# 0001856659    ukwi  1856659
# 0000217410      ul   217410
# 0000875657    ulbi   875657
# 0000831001    ulbr   831001
# 0001670076    ulcc  1670076
# 0001415311     ule  1415311
# 0001308208     ulh  1308208
# 0001605810    ulnv  1605810
# 0001403568    ulta  1403568
# 0001168220    ulur  1168220
# 0000101382    umbf   101382
# 0001033767     umc  1033767
# 0001114936   umewf  1114936
# 0000752642     umh   752642
# 0000752642  umh-pc   752642
# 0000752642  umh-pd   752642
# 0001317839    umhl  1317839
# 0001477038   umicf  1477038
# 0001477038   umicy  1477038
# 0001077771    umpq  1077771
# 0000100716    unam   100716
# 0000706863     unb   706863
# 0001453932   unblf  1453932
# 0001766140    uncy  1766140
# 0001572317    uneq  1572317
# 0001700844    unex  1700844
# 0000717954     unf   717954
# 0001020859    unfi  1020859

# %%
len('0000100517')
# Out:
# 10

# %%
ticker_to_CIK.loc['0001351548'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: '0001351548'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-acfcbfb65cf3> in <module>
# ----> 1 ticker_to_CIK.loc['0001351548'][0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '0001351548'

# %% [markdown]
# I will also need to find the historical tickers for each company. Perhaps I am looking at this the wrong way and I will need to also scrape the tickers from the files? Something to investigate.

# %% [markdown]
# #Todo verify that Yahoo finance uses the same time series/price history for AMR and AAL.

# %%
# Explain solving the mapping problem
# Working with IDs
# Explain pitfalls
# Higher predictivity due to smaller universe (by design)

# %%
ticker_to_CIK = pd.read_table('cik-lookup-data.txt', sep=r'\\t', header=None)
ticker_to_CIK.head()
# Out:
# /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                                                 0
# 0                              !J INC:0001438823:
# 1       #1 A LIFESAFER HOLDINGS, INC.:0001509607:
# 2  #1 ARIZONA DISCOUNT PROPERTIES LLC:0001457512:
# 3                   #1 PAINTBALL CORP:0001433777:
# 4                               $ LLC:0001427189:

# %%
mapping = pd.DataFrame(ticker_to_CIK[0][x].split(':') for x in range(len(ticker_to_CIK)))

# %%
mapping
# Out:
#                                          0           1 2      3     4
# 0                                   !J INC  0001438823     None  None
# 1            #1 A LIFESAFER HOLDINGS, INC.  0001509607     None  None
# 2       #1 ARIZONA DISCOUNT PROPERTIES LLC  0001457512     None  None
# 3                        #1 PAINTBALL CORP  0001433777     None  None
# 4                                    $ LLC  0001427189     None  None
# ...                                    ...         ... ..   ...   ...
# 815998            ZZIF 2008 INVESTMENT LLC  0001448632     None  None
# 815999    ZZLL INFORMATION TECHNOLOGY, INC  0001365357     None  None
# 816000                            ZZX, LLC  0001691924     None  None
# 816001               ZZYZX ZZAZX ZZOZX INC  0001184274     None  None
# 816002            ZZZ MEDIA HOLDINGS, INC.  0001755250     None  None
#
# [816003 rows x 5 columns]

# %%
mapping[1]
# Out:
# 0         0001438823
# 1         0001509607
# 2         0001457512
# 3         0001433777
# 4         0001427189
#              ...
# 815998    0001448632
# 815999    0001365357
# 816000    0001691924
# 816001    0001184274
# 816002    0001755250
# Name: 1, Length: 816003, dtype: object

# %%
res = mapping[mapping[1].isin(os.listdir('sec-edgar-filings/'))].sort_values(1)
res
# Out:
#                                          0           1 2      3     4
# 26956                  ALASKA AIRLINES INC  0000003202     None  None
# 35896              AMERICAN AIRLINES, INC.  0000004515     None  None
# 35895                AMERICAN AIRLINES INC  0000004515     None  None
# 39475                             AMR CORP  0000006201     None  None
# 35894         AMERICAN AIRLINES GROUP INC.  0000006201     None  None
# ...                                    ...         ... ..   ...   ...
# 273758    FRONTIER AIRLINES HOLDINGS, INC.  0001351548     None  None
# 29600                  ALLEGIANT TRAVEL CO  0001362468     None  None
# 324434  GULFSTREAM INTERNATIONAL GROUP INC  0001405419     None  None
# 689338               SPIRIT AIRLINES, INC.  0001498710     None  None
# 770331                 VIRGIN AMERICA INC.  0001614436     None  None
#
# [66 rows x 5 columns]

# %%
#https://www.sec.gov/Archives/edgar/cik-lookup-data.txt

# %%
[x for x in res[0]]
# Out:
# ['ALASKA AIRLINES INC',
#  'AMERICAN AIRLINES, INC.',
#  'AMERICAN AIRLINES INC',
#  'AMR CORP',
#  'AMERICAN AIRLINES GROUP INC.',
#  'DELTA AIR LINES INC /DE/',
#  'DELTA AIR LINES, INC.',
#  'HAWAIIAN AIRLINES INC/HI',
#  'HAL INC /HI/',
#  'SOUTHWEST AIRLINES CO',
#  'UNITED CONTINENTAL HOLDINGS, INC.',
#  'UAL CORP /DE/',
#  'UNITED AIRLINES HOLDINGS, INC.',
#  'UNITED AIR LINES, INC.',
#  'UNITED AIR LINES INC',
#  'UNITED AIRLINES, INC.',
#  'CONTINENTAL AIRLINES INC /DE/',
#  'CONTINENTAL AIRLINES, INC.',
#  'USAIR GROUP INC',
#  'US AIRWAYS GROUP INC',
#  'AMERICA WEST AIRLINES INC',
#  'US AIRWAYS INC',
#  'USAIR INC',
#  'USAIR INC /NEW/',
#  'ALASKA AIR GROUP INC',
#  'ALASKA AIR GROUP, INC.',
#  'SKYWEST INC',
#  'MESA AIR GROUP INC',
#  'MESA AIRLINES INC',
#  'AIRTRAN CORP',
#  'MAIR HOLDINGS INC',
#  'MESABA HOLDINGS INC',
#  'BALTIA AIR LINES INC',
#  'HARBOR BIOSCIENCES, INC.',
#  'HOLLIS EDEN PHARMACEUTICALS INC /DE/',
#  'INITIAL ACQUISITION CORP',
#  'HARBOR DIVERSIFIED, INC.',
#  'FLYI INC',
#  'ATLANTIC COAST AIRLINES INC',
#  'ATLANTIC COAST AIRLINES HOLDINGS INC',
#  'GREAT LAKES AVIATION LTD',
#  'FRONTIER AIRLINES INC /CO/',
#  'MIDWEST EXPRESS HOLDINGS INC',
#  'MIDWEST AIR GROUP INC',
#  'VALUJET INC',
#  'AIRTRAN HOLDINGS INC',
#  'VANGUARD AIRLINES INC \\\\DE\\\\',
#  'AIRNET SYSTEMS INC',
#  'AMERICA WEST HOLDINGS CORP',
#  'AIRTRAN AIRWAYS INC',
#  'NEWBRIDGE PARENT CORP',
#  'NORTHWEST AIRLINES CORP',
#  'VIVA INTERNATIONAL INC',
#  'RIVER HAWK AVIATION INC',
#  'AUXER GROUP INC',
#  'EXPRESSJET HOLDINGS INC',
#  'JETBLUE AIRWAYS CORP',
#  'REPUBLIC AIRWAYS HOLDINGS INC',
#  'PINNACLE AIRLINES CORP',
#  'HAWAIIAN HOLDINGS INC',
#  'HAWAIIAN HOLDINGS  INC',
#  'FRONTIER AIRLINES HOLDINGS, INC.',
#  'ALLEGIANT TRAVEL CO',
#  'GULFSTREAM INTERNATIONAL GROUP INC',
#  'SPIRIT AIRLINES, INC.',
#  'VIRGIN AMERICA INC.']
